# %%
import numpy as np
from scipy.stats import beta
from scipy.spatial import Voronoi
from scipy.sparse import diags
from scipy.sparse.linalg import spsolve
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, box, Point
from collections import defaultdict
from mpl_toolkits.mplot3d import Axes3D
import time
from shapely import contains_xy
from scipy.interpolate import griddata
from optimal_transport import OptimalTransport2D
from mass_update import run_mass_update_for_lambda
from concurrent.futures import ProcessPoolExecutor
import multiprocessing

# %%
# --- Parameters ---
N = 300               # Total number of samples
n_noise = 7           # Number of noise samples per corner
n_signal = N - 2 * n_noise
p = 1
np.random.seed(42)    # Reproducibility

# --- Signal from Beta(p,p) x Beta(p,p) ---
signal = np.column_stack((
    beta.rvs(p, p, size=n_signal),
    beta.rvs(p, p, size=n_signal)
))

# --- Noise cluster 1
noise1 = np.column_stack((
    beta.rvs(1, 50, size=n_noise),
    beta.rvs(1, 50, size=n_noise)
))

# --- Noise cluster 2
noise2 = np.column_stack((
    beta.rvs(50, 1, size=n_noise),
    beta.rvs(50, 1, size=n_noise)
))

# --- Combine and arrange ---
X_data = np.vstack([signal, noise1, noise2])
signal_idx = np.arange(n_signal)
noise1_idx = np.arange(n_signal, n_signal + n_noise)
noise2_idx = np.arange(n_signal + n_noise, N)

# %%
N = len(X_data)

# 1. Scatter plot of original 2D data
plt.scatter(X_data[signal_idx, 0], X_data[signal_idx, 1], color='blue', label='Signal', alpha=0.5)
plt.scatter(X_data[noise1_idx, 0], X_data[noise1_idx, 1], color='red', label='Noise near (0,0)', marker='x')
plt.scatter(X_data[noise2_idx, 0], X_data[noise2_idx, 1], color='green', label='Noise near (1,1)', marker='x')
plt.legend()
plt.grid(True)
plt.title("Simulated 2D Data: Signal vs Noise")
plt.axis('square')
plt.tight_layout()
plt.show()

# %%
lambda_list = [0.1, 1, 5, 10]

with ProcessPoolExecutor(max_workers=multiprocessing.cpu_count()) as executor:
    futures = [executor.submit(run_mass_update_for_lambda, lam, X_data) for lam in lambda_list]
    results = [future.result() for future in futures]

# %%
# check final error for comparison
for lam, masses, weights, err, iters in results:
    print(f"λ = {lam:<4}, Final error: {err:.2e}, Iterations: {iters}")
# Out:
# λ = 0.1 , Final error: 6.48e-21, Iterations: 34
# λ = 1   , Final error: 9.97e-21, Iterations: 40
# λ = 5   , Final error: 5.71e-21, Iterations: 46
# λ = 10  , Final error: 9.35e-21, Iterations: 48

# %%
plt.figure(figsize=(14, 10))

# Compute global y-limits across all lambdas
all_masses = np.concatenate([final_masses for (_, final_masses, _, _, _) in results])
ymin, ymax = all_masses.min(), all_masses.max()

for idx, (lam, final_masses, _, _, _) in enumerate(results):
    plt.subplot(2, 2, idx + 1)
    
    plt.plot(final_masses, label='Updated masses', color='blue')
    plt.plot(np.ones_like(final_masses) / len(final_masses), color='red', linestyle='--', label='Uniform masses')
    plt.axvline(noise1_idx[0], color='black', linestyle=':', label='Noise starts')
    plt.axvline(noise2_idx[0], color='gray', linestyle=':', label='2nd noise starts')

    plt.ylim(ymin, ymax)  # Set same y-limits for all plots
    plt.title(f"λ = {lam}")
    plt.xlabel("Index")
    plt.ylabel("Mass")
    plt.grid(True)
    if idx == 0:
        plt.legend()

plt.suptitle("Updated Masses vs Uniform across λ", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
bins = 30
num_resample = 10000

# --- Histogram for original X_data ---
H1, xedges, yedges = np.histogram2d(X_data[:, 0], X_data[:, 1], bins=bins, range=[[0, 1], [0, 1]])
xpos1, ypos1 = np.meshgrid(xedges[:-1] + 0.5*(xedges[1] - xedges[0]),
                           yedges[:-1] + 0.5*(yedges[1] - yedges[0]), indexing="ij")
xpos1 = xpos1.ravel()
ypos1 = ypos1.ravel()
zpos1 = np.zeros_like(xpos1)
dz1 = H1.ravel()

# --- Plot original and 4 resampled histograms ---
fig = plt.figure(figsize=(20, 5))

# Plot original X_data histogram
ax0 = fig.add_subplot(1, 5, 1, projection='3d')
ax0.bar3d(xpos1, ypos1, zpos1, dx=1/bins, dy=1/bins, dz=dz1, color='gray', zsort='average')
ax0.set_title("Original X_data")
ax0.set_xlabel("x")
ax0.set_ylabel("y")
ax0.set_zlabel("Count")

# Plot for each λ
for idx, (lam, final_masses, _, _, _) in enumerate(results):
    resampled = X_data[np.random.choice(len(X_data), size=num_resample, p=final_masses)]
    H2, _, _ = np.histogram2d(resampled[:, 0], resampled[:, 1], bins=[xedges, yedges])
    dz2 = H2.ravel()

    ax = fig.add_subplot(1, 5, idx + 2, projection='3d')
    ax.bar3d(xpos1, ypos1, zpos1, dx=1/bins, dy=1/bins, dz=dz2, color='steelblue', zsort='average')
    ax.set_title(f"Resampled (λ = {lam})")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("Count")

plt.tight_layout()
plt.show()

# %%
# --- Grid setup ---
grid_res = 100
xs = np.linspace(0, 1, grid_res)
ys = np.linspace(0, 1, grid_res)
Xg, Yg = np.meshgrid(xs, ys)

# --- Uniform weights surface ---
N = len(X_data)
uniform_weights = np.ones(N) / N
Z_uniform = griddata(X_data, uniform_weights, (Xg, Yg), method='linear', fill_value=0)

# --- Plot: 1 uniform + 4 OT weight surfaces ---
fig = plt.figure(figsize=(20, 10))

# Plot uniform once
ax0 = fig.add_subplot(2, 3, 1, projection='3d')
ax0.plot_surface(Xg, Yg, Z_uniform, cmap='viridis', edgecolor='none')
ax0.set_title("Uniform Weights Surface")
ax0.set_xlabel("x")
ax0.set_ylabel("y")
ax0.set_zlabel("Weight")

# Plot OT weights for each lambda
for idx, (lam, masses, _, _, _) in enumerate(results):
    Z_ot = griddata(X_data, masses, (Xg, Yg), method='linear', fill_value=0)

    ax = fig.add_subplot(2, 3, idx + 2, projection='3d')
    ax.plot_surface(Xg, Yg, Z_ot, cmap='plasma', edgecolor='none')
    ax.set_title(f"OT Weights Surface (λ = {lam})")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("Weight")

plt.tight_layout()
plt.show()
