# %% [markdown]
# # Wasserstein constrained ETEL

# %%
import time
import numpy as np
from optimal_transport_1d import OptimalTransport1D
from data_generator_GM import generate_GM_data
from wc_ETEL import wc_ETEL
from wc_ETEL_GM import wc_ETEL_GM
from mcmc_wcetel import single_replication
import matplotlib.pyplot as plt
from scipy.stats import beta
from numpy import log, exp
from scipy.stats import norm, gamma, wishart
import arviz as az
import sys
import subprocess
import os
import pickle
from IPython.display import display
import glob
from scipy.stats import skewnorm
from wcetel_config import nrep, N, nIter, d, burn_in, lamda, X_data, Alpha

# %%
X_data = generate_GM_data()

# %%
start_time = time.time()

# %%
# masses, log_likelihood = wc_ETEL(theta0=0, sigma0=1, lamda=5, data=X_data)

# %%
time1 = time.time()
print(f"\nRuntime: {time1 - start_time:.2f} seconds")
# Out:
# Runtime: 0.02 seconds

# %%
# # The above data size is 100 while the original code for N was 300; changed to 100
# X = X_data
# N = len(X)
# masses = np.ones(N) / N

# rho0 = lambda x: 6 * x * (1 - x)

# eta = 1e-3
# maxiter = 3000

# for i in range(maxiter):
#     ot = OptimalTransport1D(X, masses, rho0, L=1.0)
#     ot.update_weights(maxIter=1, verbose=False)
#     ww = ot.weights
    
#     masses1 = masses + eta * (-1 - np.log(N * masses) - 2 * 5 * ww)
    
#     temp = np.max(np.where((masses1 + 1 / (np.arange(1, N + 1)) * (1 - np.cumsum(masses1))) > 0)) + 1
#     right_shift = (1 / temp) * (1 - np.cumsum(masses1)[temp - 1])
#     masses1 = masses1 + right_shift
#     masses1[masses1 < 0] = 0
    
#     err = np.sum((masses - masses1) ** 2)
#     if err <= 1e-50:
#         break

#     # print(f"Iteration {i}: Error = {err:.2e}")
#     masses = masses1

# %%
# # error is 0 because 1e-50 is too small and just 0 for the machine
# print(f"Final error after convergence: {err:.2e}")

# %%
time2 = time.time()
print(f"\nRuntime: {time2 - time1:.2f} seconds")
# Out:
# Runtime: 0.02 seconds

# %%
# # 1. Histogram of original data
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 3, 1)
# plt.hist(X_data, bins=40, edgecolor='black')
# plt.title("Histogram of Original Data")

# # 2. Plot centering density Beta(2,2)
# grid = np.linspace(0, 1, 100)
# plt.subplot(1, 3, 2)
# plt.plot(grid, beta.pdf(grid, 2, 2), label='Beta(2,2)', color='blue')
# plt.title("Centering Density: Beta(2,2)")
# plt.xlabel("x")
# plt.ylabel("Density")
# plt.legend()

# # 3. Plot updated weights vs uniform
# plt.subplot(1, 3, 3)
# plt.plot(masses1, label='Updated weights', color='blue')
# plt.plot(np.ones(N) / N, label='Uniform weights', color='red', linestyle='--')
# plt.title("Updated Weights vs Uniform")
# plt.xlabel("Index")
# plt.ylabel("Weight")
# plt.legend()

# plt.tight_layout()
# plt.show()

# # 4. Resample using updated weights
# X_data_tilde = np.random.choice(X_data, size=N, p=masses1, replace=True)

# # 5. Histogram of resampled data
# plt.hist(X_data_tilde, bins=40, edgecolor='black')
# plt.title("Histogram of Resampled Data")
# plt.show()

# %%
# N = 100; d = 1
# Alpha = 5
# lamda = 3

# ## use the following part for simulations for a grid of sample size
# # Alpha = rep(2, d)
# # N_grid = c(100, 200, 300, 500)
# # BF = matrix(NA, nrow = length(N_grid), ncol = 3)
# # colnames(BF) <- c("Sample size", "M1", "M2")

# #### Simulation control
# # epsilon = 2.25 # Change value of \varepsilon or use a grid
# # epsilon_grid = c(2.25, 3, 2^2, 2^3, 2^4)
# nrep = 1
# nIter = 100

# burn_in = nIter // 2

# %%
# result = subprocess.run(
#     [sys.executable, "parallel_mcmc_runner.py"],
#     capture_output=True,
#     text=True
# )

# print("STDOUT:")
# print(result.stdout)
# print("STDERR:")
# print(result.stderr)
# Out:
# STDOUT:
# Running replication: 0
#
# STDERR:
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(

# %%
# results_files = sorted(glob.glob("wcETEL_MCMC_results/*.pkl"))

# all_results = []

# for file in results_files:
#     with open(file, "rb") as f:
#         result = pickle.load(f)
#         all_results.append(result)

# print(result)
# Out:
# {'M1_Marglik': np.float64(-460.54342132865037), 'MS1_elpd': np.float64(-460.5497098631463), 'MS1_se': np.float64(0.25779536047452634), 'MH_storage': array([-460.55124913, -460.55205956, -460.55205956, -460.54970427,
#        -460.54916837, -460.55041667, -460.55148   , -460.55148   ,
#        -460.55148   , -460.54958107, -460.55027016, -460.55068246,
#        -460.55045314, -460.55271965, -460.55271965, -460.55217822,
#        -460.55097992, -460.5509951 , -460.55014252, -460.54802454,
#        -460.54964989, -460.54873664, -460.54804384, -460.55008669,
#        -460.54770689, -460.55128776, -460.54924474, -460.55309553,
#        -460.54988991, -460.54706048, -460.55057156, -460.54932087,
#        -460.54896339, -460.54941873, -460.55056899, -460.54801308,
#        -460.55031777, -460.54928315, -460.55032946, -460.55192605,
#        -460.55025798, -460.54651442, -460.54899427, -460.54953654,
#        -460.54836766, -460.54940912, -460.5497214 , -460.55183866,
#        -460.55004703, -460.54927373, -460.54822731, -460.54979006,
#        -460.54342133, -460.54949845, -460.55082824, -460.54833667,
#        -460.55067833, -460.55200629, -460.55038127, -460.54984038,
#        -460.54895801, -460.54741575, -460.55002242, -460.54993969,
#        -460.54915172, -460.54953465, -460.55025136, -460.54933691,
#        -460.550373  , -460.550373  , -460.55000892, -460.54958961,
#        -460.54890507, -460.55025852, -460.55025852, -460.55025852,
#        -460.54741198, -460.54785346, -460.54910752, -460.55156919,
#        -460.55080252, -460.55084134, -460.55100884, -460.5507254 ,
#        -460.55091675, -460.55081988, -460.54963697, -460.54876379,
#        -460.54755839, -460.54916678, -460.55049769, -460.5523066 ,
#        -460.5493988 , -460.54712996, -460.54927857, -460.55010628,
#        -460.54954614, -460.54922078, -460.5525181 , -460.55081113]), 'mu_Storage': array([[10.25487045],
#        [ 8.0890666 ],
#        [ 8.0890666 ],
#        [ 5.4344324 ],
#        [ 3.89396133],
#        [ 7.29371391],
#        [ 3.93476361],
#        [ 3.93476361],
#        [ 3.93476361],
#        [ 7.44848642],
#        [ 4.41393448],
#        [ 3.02090769],
#        [11.72022092],
#        [15.23970164],
#        [15.23970164],
#        [18.85794752],
#        [15.81584797],
#        [21.04843801],
#        [16.6206325 ],
#        [20.73794927],
#        [19.43719185],
#        [23.78273396],
#        [22.73654309],
#        [29.47266864],
#        [33.53743513],
#        [32.47083281],
#        [33.89424736],
#        [36.31563918],
#        [36.21328265],
#        [37.70546938],
#        [35.42416374],
#        [30.46397266],
#        [29.52325451],
#        [34.92392764],
#        [37.70730061],
#        [34.09929646],
#        [36.55265179],
#        [41.98044891],
#        [46.29655474],
#        [47.92813738],
#        [48.91365731],
#        [43.88215677],
#        [45.56502433],
#        [45.63333542],
#        [47.9266156 ],
#        [48.18591322],
#        [44.5927668 ],
#        [45.99329509],
#        [44.48000633],
#        [49.40262098],
#        [47.53379955],
#        [48.11030379],
#        [48.79705098],
#        [47.86752558],
#        [55.43627239],
#        [55.11916165],
#        [57.01353829],
#        [54.57950398],
#        [58.0742971 ],
#        [55.34496822],
#        [50.95763792],
#        [54.16916759],
#        [50.27462109],
#        [49.40486568],
#        [50.53716718],
#        [54.0332171 ],
#        [55.03529766],
#        [56.5881716 ],
#        [51.58572562],
#        [51.58572562],
#        [53.70255768],
#        [53.68096962],
#        [53.26151934],
#        [55.3916103 ],
#        [55.3916103 ],
#        [55.3916103 ],
#        [59.89858949],
#        [55.96093772],
#        [51.0972907 ],
#        [45.5087081 ],
#        [41.41568925],
#        [34.37480241],
#        [34.96351275],
#        [32.52581824],
#        [29.95802736],
#        [34.28629533],
#        [39.32289232],
#        [38.46233478],
#        [35.74074268],
#        [37.39663499],
#        [36.74407366],
#        [36.22003618],
#        [35.81185913],
#        [40.39942839],
#        [43.31756672],
#        [43.20285157],
#        [42.05711414],
#        [37.84288464],
#        [34.59084392],
#        [32.97917899]]), 'Sigma_Storage': array([[1401.13831387],
#        [1529.02811355],
#        [1529.02811355],
#        [1203.86126544],
#        [1146.51718853],
#        [1288.27814584],
#        [1435.29886723],
#        [1435.29886723],
#        [1435.29886723],
#        [1190.36889667],
#        [1269.95418185],
#        [1322.2542143 ],
#        [1293.08194678],
#        [1650.16365403],
#        [1650.16365403],
#        [1549.94120994],
#        [1363.04574509],
#        [1365.35355554],
#        [1255.0579953 ],
#        [1039.90571692],
#        [1198.49493222],
#        [1104.75988617],
#        [1041.66547717],
#        [1248.87878933],
#        [1013.64883055],
#        [1407.55943328],
#        [1155.70603299],
#        [1727.60326496],
#        [1226.10654496],
#        [ 962.79963974],
#        [1309.04492406],
#        [1163.52192427],
#        [1127.06908794],
#        [1173.99354462],
#        [1308.7711703 ],
#        [1039.4637677 ],
#        [1277.05178038],
#        [1159.91517099],
#        [1278.71164257],
#        [1507.61759889],
#        [1269.97161348],
#        [ 923.22145702],
#        [1130.59243287],
#        [1186.91023498],
#        [1071.15053301],
#        [1173.29101775],
#        [1207.22557868],
#        [1493.18737862],
#        [1244.58207788],
#        [1159.08916618],
#        [1058.55925972],
#        [1215.0044181 ],
#        [ 741.90343522],
#        [1182.83846486],
#        [1343.27805399],
#        [1068.47264212],
#        [1323.32928484],
#        [1521.14424228],
#        [1285.30633874],
#        [1220.81690517],
#        [1127.0972009 ],
#        [ 990.66406172],
#        [1241.79079696],
#        [1232.13437414],
#        [1146.54787622],
#        [1186.84583963],
#        [1269.24933777],
#        [1165.79089858],
#        [1284.19999289],
#        [1284.19999289],
#        [1240.2573801 ],
#        [1192.82136616],
#        [1121.91594228],
#        [1270.12768483],
#        [1270.12768483],
#        [1270.12768483],
#        [ 990.44000219],
#        [1026.40503445],
#        [1142.06554631],
#        [1450.30442319],
#        [1339.59320745],
#        [1344.66121727],
#        [1367.69203193],
#        [1329.08252997],
#        [1354.81358786],
#        [1341.76025827],
#        [1197.73975316],
#        [1107.87751457],
#        [1001.60870471],
#        [1147.79021659],
#        [1299.61194362],
#        [1573.17426475],
#        [1171.90307776],
#        [ 968.15458769],
#        [1159.46947979],
#        [1251.57292669],
#        [1187.87375262],
#        [1153.34742037],
#        [1611.99448666],
#        [1340.54685685]]), 'loglik_mat': array([[-4.58362674, -4.58677001, -4.58815677, ..., -4.67081562,
#         -4.67082087, -4.67085486],
#        [-4.58344845, -4.58660649, -4.58799981, ..., -4.67160151,
#         -4.67160677, -4.67164085],
#        [-4.58344845, -4.58660649, -4.58799981, ..., -4.67160151,
#         -4.67160677, -4.67164085],
#        ...,
#        [-4.58408236, -4.58718797, -4.58855802, ..., -4.66880797,
#         -4.66881317, -4.66884693],
#        [-4.58334826, -4.58651466, -4.58791167, ..., -4.67204221,
#         -4.67204748, -4.67208162],
#        [-4.58372365, -4.58685896, -4.58824218, ..., -4.67038709,
#         -4.67039232, -4.67042627]], shape=(100, 100))}

# %%
time3 = time.time()
print(f"\nRuntime: {time3 - time2:.2f} seconds")
# Out:
# Runtime: 4045.92 seconds

# %%
# MH_storage = result['MH_storage']
# loglik_mat = result['loglik_mat']
# mu_Storage = result['mu_Storage']

# %%
# Epsilon grid (convert R: 2^2, 2^3, 2^4 -> Python)
epsilon_grid = [2.25, 3, 4, 8, 16]

M1_varying_epsilon = np.full((len(epsilon_grid), 4), np.nan)

for i_eps, epsilon in enumerate(epsilon_grid):
    M1_Results = np.full((nrep, 3), np.nan)

    for m in range(nrep):
        np.random.seed(123 + m)

        # Generate skew normal data
        x = skewnorm.rvs(a=Alpha, loc=0, scale=1, size=N)
        x = np.sort(x)

        # Call the modularized MCMC function
        result = single_replication(m, lamda=epsilon, N=N, nIter=nIter, d=1, burn_in=burn_in, X_data = x)

        # Extract returned variables
        MH_storage = result['MH_storage']
        loglik_mat = result['loglik_mat']
        mu_Storage = result['mu_Storage']

        # Compute marginal likelihood
        post_prob = np.exp(MH_storage - np.max(MH_storage))
        post_prob /= np.sum(post_prob)
        M1_Marglik = np.max(MH_storage) - np.log(np.sum(post_prob))

        # ArviZ reshaping for correct dimensions
        loglik_post_burnin = loglik_mat[burn_in:, :].reshape((1, -1, N))
        idata = az.from_dict(
            posterior={"mu": mu_Storage[burn_in:, :].reshape((1, -1, 1))},
            log_likelihood={"likelihood": loglik_post_burnin},
            coords={"obs_id": np.arange(N)},
            dims={"likelihood": ["obs_id"]}
        )

        # Run ArviZ LOO
        loo_result = az.loo(idata, pointwise=True)
        pareto_k = loo_result.pareto_k
        MS1_elpd = loo_result.elpd_loo
        MS1_se = loo_result.se

        # # Print diagnostic info
        # print("Max Pareto k:", np.max(pareto_k))
        # print("Num of points with k > 0.7:", np.sum(pareto_k > 0.7))
        # print("Num of points with k > 1.0:", np.sum(pareto_k > 1.0))

        M1_Results[m, :] = [M1_Marglik, MS1_elpd, MS1_se]

    M1_varying_epsilon[i_eps, :] = [epsilon, *np.nanmean(M1_Results, axis=0)]
# Out:
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.41 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(

# %%
for row in M1_varying_epsilon:
    print(f"Epsilon: {row[0]:>5}, MargLik: {row[1]:>10.4f}, ELPD: {row[2]:>10.4f}, SE: {row[3]:>6.4f}")

plt.plot(M1_varying_epsilon[:,0], M1_varying_epsilon[:,1], marker='o', label="MargLik")
plt.plot(M1_varying_epsilon[:,0], M1_varying_epsilon[:,2], marker='x', label="ELPD")
plt.xlabel("Epsilon")
plt.ylabel("Log-likelihood")
plt.legend()
plt.show()
# Out:
# Epsilon:  2.25, MargLik:  -460.5170, ELPD:  -460.5170, SE: 0.0011
# Epsilon:   3.0, MargLik:  -460.5170, ELPD:  -460.5170, SE: 0.0014
# Epsilon:   4.0, MargLik:  -460.5170, ELPD:  -460.5170, SE: 0.0019
# Epsilon:   8.0, MargLik:  -460.5170, ELPD:  -460.5170, SE: 0.0039
# Epsilon:  16.0, MargLik:  -460.5170, ELPD:  -460.5171, SE: 0.0078

# %%
time4 = time.time()
print(f"\nRuntime: {time4 - time3:.2f} seconds")
# Out:
# Runtime: 10808.52 seconds

# %%
result2 = subprocess.run(
    [sys.executable, "parallel_mcmc_mixture_runner.py"],
    capture_output=True,
    text=True
)

print("STDOUT:")
print(result2.stdout)
print("STDERR:")
print(result2.stderr)

# %%
results_files2 = sorted(glob.glob("wcETEL_MCMC_results_M2/*.pkl"))

all_results2 = []

for file in results_files2:
    with open(file, "rb") as f:
        result = pickle.load(f)
        all_results2.append(result)

print(all_results2[0])

# %%
end_time = time.time()
print(f"\nRuntime: {end_time - time4:.2f} seconds")
print(f"\nTotal Runtime: {end_time - start_time:.2f} seconds")

# %%
M1_Marglik_array = np.array([res['M1_Marglik'] for res in all_results])
M1_elpd_array = np.array([res['MS1_elpd'] for res in all_results])
M1_se_array = np.array([res['MS1_se'] for res in all_results])
M2_Marglik_array = np.array([res['M2_Marglik'] for res in all_results2])
M2_elpd_array = np.array([res['MS2_elpd'] for res in all_results2])
M2_se_array = np.array([res['MS2_se'] for res in all_results2])

M1_Results = np.column_stack((M1_Marglik_array, M1_elpd_array, M1_se_array))
M2_Results = np.column_stack((M2_Marglik_array, M2_elpd_array, M2_se_array))

print("M1 Results:")
print(M1_Results)
print("\nM2 Results:")
print(M2_Results)
