# %% [markdown]
# # Wasserstein constrained ETEL

# %%
import time
import numpy as np
from optimal_transport_1d import OptimalTransport1D
from data_generator_GM import generate_GM_data
from wc_ETEL import wc_ETEL
from wc_ETEL_GM import wc_ETEL_GM
from mcmc_wcetel import single_replication
import matplotlib.pyplot as plt
from scipy.stats import beta
from numpy import log, exp
from scipy.stats import norm, gamma, wishart
import arviz as az
import sys
import subprocess
import os
import pickle
from IPython.display import display
import glob
from scipy.stats import skewnorm

# %%
X_data = generate_GM_data()

# %%
start_time = time.time()

# %%
# masses, log_likelihood = wc_ETEL(theta0=0, sigma0=1, lamda=5, data=X_data)

# %%
time1 = time.time()
print(f"\nRuntime: {time1 - start_time:.2f} seconds")
# Out:
# Runtime: 0.02 seconds

# %%
# # The above data size is 100 while the original code for N was 300; changed to 100
# X = X_data
# N = len(X)
# masses = np.ones(N) / N

# rho0 = lambda x: 6 * x * (1 - x)

# eta = 1e-3
# maxiter = 3000

# for i in range(maxiter):
#     ot = OptimalTransport1D(X, masses, rho0, L=1.0)
#     ot.update_weights(maxIter=1, verbose=False)
#     ww = ot.weights
    
#     masses1 = masses + eta * (-1 - np.log(N * masses) - 2 * 5 * ww)
    
#     temp = np.max(np.where((masses1 + 1 / (np.arange(1, N + 1)) * (1 - np.cumsum(masses1))) > 0)) + 1
#     right_shift = (1 / temp) * (1 - np.cumsum(masses1)[temp - 1])
#     masses1 = masses1 + right_shift
#     masses1[masses1 < 0] = 0
    
#     err = np.sum((masses - masses1) ** 2)
#     if err <= 1e-50:
#         break

#     # print(f"Iteration {i}: Error = {err:.2e}")
#     masses = masses1

# %%
# # error is 0 because 1e-50 is too small and just 0 for the machine
# print(f"Final error after convergence: {err:.2e}")

# %%
time2 = time.time()
print(f"\nRuntime: {time2 - time1:.2f} seconds")
# Out:
# Runtime: 0.03 seconds

# %%
# # 1. Histogram of original data
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 3, 1)
# plt.hist(X_data, bins=40, edgecolor='black')
# plt.title("Histogram of Original Data")

# # 2. Plot centering density Beta(2,2)
# grid = np.linspace(0, 1, 100)
# plt.subplot(1, 3, 2)
# plt.plot(grid, beta.pdf(grid, 2, 2), label='Beta(2,2)', color='blue')
# plt.title("Centering Density: Beta(2,2)")
# plt.xlabel("x")
# plt.ylabel("Density")
# plt.legend()

# # 3. Plot updated weights vs uniform
# plt.subplot(1, 3, 3)
# plt.plot(masses1, label='Updated weights', color='blue')
# plt.plot(np.ones(N) / N, label='Uniform weights', color='red', linestyle='--')
# plt.title("Updated Weights vs Uniform")
# plt.xlabel("Index")
# plt.ylabel("Weight")
# plt.legend()

# plt.tight_layout()
# plt.show()

# # 4. Resample using updated weights
# X_data_tilde = np.random.choice(X_data, size=N, p=masses1, replace=True)

# # 5. Histogram of resampled data
# plt.hist(X_data_tilde, bins=40, edgecolor='black')
# plt.title("Histogram of Resampled Data")
# plt.show()

# %%
N = 100; d = 1
Alpha = 5
lamda = 3

## use the following part for simulations for a grid of sample size
# Alpha = rep(2, d)
# N_grid = c(100, 200, 300, 500)
# BF = matrix(NA, nrow = length(N_grid), ncol = 3)
# colnames(BF) <- c("Sample size", "M1", "M2")

#### Simulation control
# epsilon = 2.25 # Change value of \varepsilon or use a grid
# epsilon_grid = c(2.25, 3, 2^2, 2^3, 2^4)
nrep = 1
nIter = 10

burn_in = nIter // 2

# %%
result = subprocess.run(
    [sys.executable, "parallel_mcmc_runner.py"],
    capture_output=True,
    text=True
)

print("STDOUT:")
print(result.stdout)
print("STDERR:")
print(result.stderr)
# Out:
# STDOUT:
# Running replication: 0
#
# STDERR:
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(

# %%
results_files = sorted(glob.glob("wcETEL_MCMC_results/*.pkl"))

all_results = []

for file in results_files:
    with open(file, "rb") as f:
        result = pickle.load(f)
        all_results.append(result)

print(result)
# Out:
# {'M1_Marglik': np.float64(-460.54916836682276), 'MS1_elpd': np.float64(-460.5508921652464), 'MS1_se': np.float64(0.2625598032086288), 'MH_storage': array([-460.55124913, -460.55205956, -460.55205956, -460.54970427,
#        -460.54916837, -460.55041667, -460.55148   , -460.55148   ,
#        -460.55148   , -460.54958107]), 'mu_Storage': array([[10.25487045],
#        [ 8.0890666 ],
#        [ 8.0890666 ],
#        [ 5.4344324 ],
#        [ 3.89396133],
#        [ 7.29371391],
#        [ 3.93476361],
#        [ 3.93476361],
#        [ 3.93476361],
#        [ 7.44848642]]), 'Sigma_Storage': array([[1401.13831387],
#        [1529.02811355],
#        [1529.02811355],
#        [1203.86126544],
#        [1146.51718853],
#        [1288.27814584],
#        [1435.29886723],
#        [1435.29886723],
#        [1435.29886723],
#        [1190.36889667]]), 'loglik_mat': array([[-4.58362674, -4.58677001, -4.58815677, -4.58826473, -4.58867086,
#         -4.58875696, -4.58916275, -4.58958607, -4.58976171, -4.59060763,
#         -4.59069754, -4.59096559, -4.59104129, -4.59160479, -4.59194529,
#         -4.59227566, -4.59233085, -4.59236623, -4.5924435 , -4.59251851,
#         -4.59270006, -4.59301072, -4.5932585 , -4.59331114, -4.59347152,
#         -4.59370163, -4.59398002, -4.59398467, -4.59426929, -4.59441154,
#         -4.59446736, -4.59456088, -4.59457282, -4.59461576, -4.59474776,
#         -4.59478081, -4.59509566, -4.59512188, -4.595183  , -4.59530275,
#         -4.59546088, -4.59570307, -4.59593749, -4.59595675, -4.59596964,
#         -4.59600066, -4.59616277, -4.59618383, -4.59622635, -4.5962565 ,
#         -4.5962603 , -4.59631613, -4.59664022, -4.59666707, -4.5967181 ,
#         -4.59682569, -4.59684632, -4.59687684, -4.59688174, -4.59689979,
#         -4.59693753, -4.59696968, -4.59700775, -4.59701338, -4.59736984,
#         -4.59750864, -4.59756555, -4.5975939 , -4.59773869, -4.59779718,
#         -4.59787351, -4.59791624, -4.59814658, -4.59823323, -4.59827002,
#         -4.59855227, -4.59857041, -4.59859203, -4.59859836, -4.59863815,
#         -4.59886254, -4.59895699, -4.5989812 , -4.59902491, -4.59923919,
#         -4.59925884, -4.66957226, -4.67009277, -4.67025361, -4.6703794 ,
#         -4.67044932, -4.6704933 , -4.67056444, -4.67058361, -4.67069334,
#         -4.67077449, -4.6707932 , -4.67081562, -4.67082087, -4.67085486],
#        [-4.58344845, -4.58660649, -4.58799981, -4.58810829, -4.58851635,
#         -4.59397216, -4.59424729, -4.59425188, -4.59453312, -4.59467366,
#         -4.5947288 , -4.59482118, -4.59483297, -4.59487537, -4.59500571,
#         -4.59503834, -4.59534915, -4.59537502, -4.59543534, -4.5955535 ,
#         -4.59570951, -4.59594841, -4.59617961, -4.5961986 , -4.59621131,
#         -4.59624189, -4.59640165, -4.5964224 , -4.59646429, -4.59649399,
#         -4.59649772, -4.5965527 , -4.59687168, -4.5968981 , -4.5969483 ,
#         -4.59705411, -4.59707439, -4.59710439, -4.59710921, -4.59712694,
#         -4.59716399, -4.59719555, -4.5972329 , -4.59723842, -4.59758784,
#         -4.59772383, -4.59777955, -4.5978073 , -4.59794893, -4.59800611,
#         -4.59808068, -4.59812239, -4.59834707, -4.59843153, -4.59846734,
#         -4.59874191, -4.59875954, -4.59878052, -4.59878666, -4.59882516,
#         -4.59904194, -4.59913302, -4.59915631, -4.59919827, -4.59940336,
#         -4.59942211, -4.6679337 , -4.66845082, -4.66861063, -4.66873562,
#         -4.66880509, -4.66884879, -4.66891947, -4.66893852, -4.66904755,
#         -4.66912818, -4.66914678, -4.66916905, -4.66917427, -4.66920807]])}

# %%
time3 = time.time()
print(f"\nRuntime: {time3 - time2:.2f} seconds")
# Out:
# Runtime: 465.88 seconds

# %%
# MH_storage = result['MH_storage']
# loglik_mat = result['loglik_mat']
# mu_Storage = result['mu_Storage']

# %%
# Epsilon grid (convert R: 2^2, 2^3, 2^4 -> Python)
epsilon_grid = [2.25, 3, 4, 8, 16]

M1_varying_epsilon = np.full((len(epsilon_grid), 4), np.nan)

for i_eps, epsilon in enumerate(epsilon_grid):
    M1_Results = np.full((nrep, 3), np.nan)

    for m in range(nrep):
        np.random.seed(123 + m)

        # Generate skew normal data
        x = skewnorm.rvs(a=Alpha, loc=0, scale=1, size=N)
        x = np.sort(x)

        # Call the modularized MCMC function
        result = single_replication(m, lamda=epsilon, N=N, nIter=nIter, d=1, burn_in=burn_in, X_data = x)

        # Extract returned variables
        MH_storage = result['MH_storage']
        loglik_mat = result['loglik_mat']
        mu_Storage = result['mu_Storage']

        # Compute marginal likelihood
        post_prob = np.exp(MH_storage - np.max(MH_storage))
        post_prob /= np.sum(post_prob)
        M1_Marglik = np.max(MH_storage) - np.log(np.sum(post_prob))

        # ArviZ reshaping for correct dimensions
        loglik_post_burnin = loglik_mat[burn_in:, :].reshape((1, -1, N))
        idata = az.from_dict(
            posterior={"mu": mu_Storage[burn_in:, :].reshape((1, -1, 1))},
            log_likelihood={"likelihood": loglik_post_burnin},
            coords={"obs_id": np.arange(N)},
            dims={"likelihood": ["obs_id"]}
        )

        # Run ArviZ LOO
        loo_result = az.loo(idata, pointwise=True)
        pareto_k = loo_result.pareto_k
        MS1_elpd = loo_result.elpd_loo
        MS1_se = loo_result.se

        # # Print diagnostic info
        # print("Max Pareto k:", np.max(pareto_k))
        # print("Num of points with k > 0.7:", np.sum(pareto_k > 0.7))
        # print("Num of points with k > 1.0:", np.sum(pareto_k > 1.0))

        M1_Results[m, :] = [M1_Marglik, MS1_elpd, MS1_se]

    M1_varying_epsilon[i_eps, :] = [epsilon, *np.nanmean(M1_Results, axis=0)]
# Out:
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(

# %%
for row in M1_varying_epsilon:
    print(f"Epsilon: {row[0]:>5}, MargLik: {row[1]:>10.4f}, ELPD: {row[2]:>10.4f}, SE: {row[3]:>6.4f}")

plt.plot(M1_varying_epsilon[:,0], M1_varying_epsilon[:,1], marker='o', label="MargLik")
plt.plot(M1_varying_epsilon[:,0], M1_varying_epsilon[:,2], marker='x', label="ELPD")
plt.xlabel("Epsilon")
plt.ylabel("Log-likelihood")
plt.legend()
plt.show()
# Out:
# Epsilon:  2.25, MargLik:  -460.5170, ELPD:  -460.5170, SE: 0.0000
# Epsilon:   3.0, MargLik:  -460.5170, ELPD:  -460.5170, SE: 0.0000
# Epsilon:   4.0, MargLik:  -460.5170, ELPD:  -460.5170, SE: 0.0000
# Epsilon:   8.0, MargLik:  -460.5170, ELPD:  -460.5170, SE: 0.0002
# Epsilon:  16.0, MargLik:  -460.5170, ELPD:  -460.5170, SE: 0.0007

# %%
time4 = time.time()
print(f"\nRuntime: {time4 - time3:.2f} seconds")
# Out:
# Runtime: 914.92 seconds

# %%
result2 = subprocess.run(
    [sys.executable, "parallel_mcmc_mixture_runner.py"],
    capture_output=True,
    text=True
)

print("STDOUT:")
print(result2.stdout)
print("STDERR:")
print(result2.stderr)
# Out:
# STDOUT:
# Running replication: 0
#
# STDERR:
# C:\Users\12822\AppData\Local\Programs\Python\Python313\Lib\site-packages\arviz\stats\stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than -0.43 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(

# %%
results_files2 = sorted(glob.glob("wcETEL_MCMC_results_M2/*.pkl"))

all_results2 = []

for file in results_files2:
    with open(file, "rb") as f:
        result = pickle.load(f)
        all_results2.append(result)

print(all_results2[0])
# Out:
# {'M2_Marglik': np.float64(-460.5484127771188), 'MS2_elpd': np.float64(-460.5508708152432), 'MS2_se': np.float64(0.2624043612609818), 'MH_storage': array([-460.54874064, -460.5485981 , -460.55162001, -460.55031668,
#        -460.54841278, -460.54841278, -460.55081103, -460.55245523,
#        -460.55164403, -460.55095941]), 'mu_Storage': array([[10.25487045, 17.55532218],
#        [ 1.60744804, 16.21430811],
#        [-0.11311332, 14.94319518],
#        [-4.30783823, 18.91833811],
#        [-5.34971942,  9.91212438],
#        [-5.34971942,  9.91212438],
#        [ 3.17326141, 11.17127756],
#        [ 3.28605968, 14.95069619],
#        [ 0.17264629, 18.10645063],
#        [ 0.35941207, 17.26953241]]), 'loglik_mat': array([[-4.58419322, -4.58728952, -4.58865544, -4.58876178, -4.58916173,
#         -4.58924651, -4.58964607, -4.59006283, -4.59023574, -4.59106841,
#         -4.5911569 , -4.5914207 , -4.59149519, -4.59204964, -4.59238463,
#         -4.59270962, -4.5927639 , -4.59279869, -4.59287468, -4.59294843,
#         -4.59312691, -4.59343229, -4.59367582, -4.59372755, -4.59388514,
#         -4.5941112 , -4.59438466, -4.59438923, -4.59466872, -4.59480838,
#         -4.59486318, -4.59495497, -4.59496669, -4.59500881, -4.5951383 ,
#         -4.59517072, -4.59547945, -4.59550515, -4.59556505, -4.5956824 ,
#         -4.59688477, -4.59691706, -4.5969553 , -4.59696095, -4.59731905,
#         -4.59745851, -4.59751568, -4.59754418, -4.5976897 , -4.5977485 ,
#         -4.59782524, -4.59786821, -4.59809986, -4.59818703, -4.59822404,
#         -4.59850809, -4.59852634, -4.59854811, -4.59855449, -4.59859457,
#         -4.59882073, -4.59891597, -4.59894039, -4.59898451, -4.59920094,
#         -4.59922079, -4.66995445, -4.67047576, -4.67063684, -4.67076282,
#         -4.67083284, -4.67087688, -4.67094813, -4.67096733, -4.67107722,
#         -4.67115849, -4.67117723, -4.67119968, -4.67120494, -4.67123897],
#        [-4.58369104, -4.58682898, -4.58821337, -4.58832115, -4.58872657,
#         -4.58881252, -4.58921761, -4.58964018, -4.58981551, -4.59065993,
#         -4.59074967, -4.59101724, -4.5910928 , -4.59165528, -4.59199515,
#         -4.59232491, -4.59237999, -4.59241531, -4.59249244, -4.5925673 ,
#         -4.5927485 , -4.59305857, -4.59330586, -4.5933584 , -4.59351846,
#         -4.59374811, -4.59402594, -4.59403058, -4.59431462, -4.59445657,
#         -4.59451228, -4.5946056 , -4.59461752, -4.59466036, -4.59479208,
#         -4.59482506, -4.59513922, -4.59516538, -4.59522636, -4.59534583,
#         -4.5955036 , -4.59574522, -4.59597909, -4.59599831, -4.59601117,
#         -4.59604211, -4.59620382, -4.59622482, -4.59626723, -4.59629731,
#         -4.59630109, -4.59635678, -4.59667999, -4.59670677, -4.59675765,
#         -4.59686494, -4.59688551, -4.59691593, -4.59692082, -4.59693882,
#         -4.59697644, -4.59700849, -4.59704644, -4.59705205, -4.5974073 ,
#         -4.59754562, -4.59760232, -4.59763057, -4.59777481, -4.59783308,
#         -4.59790911, -4.59795166, -4.59818103, -4.5982673 , -4.59830392,
#         -4.59858486, -4.59860291, -4.59862442, -4.59863072, -4.59867028,
#         -4.59889337, -4.59898724, -4.59901129, -4.5990547 , -4.5992674 ,
#         -4.5992869 , -4.66929051, -4.66981043, -4.6699711 , -4.67009675,
#         -4.67016659, -4.67021052, -4.67028158, -4.67030073, -4.67041034,
#         -4.6704914 , -4.67051009, -4.67053249, -4.67053773, -4.67057169]])}

# %%
end_time = time.time()
print(f"\nRuntime: {end_time - time4:.2f} seconds")
print(f"\nTotal Runtime: {end_time - start_time:.2f} seconds")
# Out:
# Runtime: 800.67 seconds
#
# Total Runtime: 2181.51 seconds

# %%
M1_Marglik_array = np.array([res['M1_Marglik'] for res in all_results])
M1_elpd_array = np.array([res['MS1_elpd'] for res in all_results])
M1_se_array = np.array([res['MS1_se'] for res in all_results])
M2_Marglik_array = np.array([res['M2_Marglik'] for res in all_results2])
M2_elpd_array = np.array([res['MS2_elpd'] for res in all_results2])
M2_se_array = np.array([res['MS2_se'] for res in all_results2])

M1_Results = np.column_stack((M1_Marglik_array, M1_elpd_array, M1_se_array))
M2_Results = np.column_stack((M2_Marglik_array, M2_elpd_array, M2_se_array))

print("M1 Results:")
print(M1_Results)
print("\nM2 Results:")
print(M2_Results)
# Out:
# M1 Results:
# [[-4.60549168e+02 -4.60550892e+02  2.62559803e-01]]
#
# M2 Results:
# [[-4.60548413e+02 -4.60550871e+02  2.62404361e-01]]
